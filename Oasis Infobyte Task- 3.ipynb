# %% [markdown]
# # Oasis Infobyte Task 3
#
#
# Priya Dharshini G J

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CarPrice_Assignment.csv')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (205, 26)

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
#splitted the carname column into companyname and carmodel columns
df[['CompanyName','Carmodel']] = df['CarName'].str.split(' ',1,expand=True)

# %%
df.head(50)
# Out:
#     car_ID  symboling                    CarName fueltype aspiration  \
# 0        1          3         alfa-romero giulia      gas        std
# 1        2          3        alfa-romero stelvio      gas        std
# 2        3          1   alfa-romero Quadrifoglio      gas        std
# 3        4          2                audi 100 ls      gas        std
# 4        5          2                 audi 100ls      gas        std
# 5        6          2                   audi fox      gas        std
# 6        7          1                 audi 100ls      gas        std
# 7        8          1                  audi 5000      gas        std
# 8        9          1                  audi 4000      gas      turbo
# 9       10          0        audi 5000s (diesel)      gas      turbo
# 10      11          2                   bmw 320i      gas        std
# 11      12          0                   bmw 320i      gas        std
# 12      13          0                     bmw x1      gas        std
# ...

# %%
#dropped CarName and carid column
df = df.drop(['CarName','car_ID'],axis=1)

# %%
df.columns
# Out:
# Index(['symboling', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price', 'CompanyName', 'Carmodel'],
#       dtype='object')

# %%
df['CompanyName'].value_counts().index.tolist()
# Out:
# ['toyota',
#  'nissan',
#  'mazda',
#  'honda',
#  'mitsubishi',
#  'subaru',
#  'peugeot',
#  'volvo',
#  'volkswagen',
#  'dodge',
#  'buick',
#  'bmw',
#  'audi',
#  'plymouth',
#  'saab',
#  'isuzu',
#  'porsche',
#  'alfa-romero',
#  'chevrolet',
#  'jaguar',
#  'vw',
#  'maxda',
#  'renault',
#  'toyouta',
#  'vokswagen',
#  'Nissan',
#  'mercury',
#  'porcshce']

# %%
#drop duplicates
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['symboling', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price', 'CompanyName', 'Carmodel'],
#       dtype='object')

# %%
df.dtypes
# Out:
# symboling             int64
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# CompanyName          object
# Carmodel             object
# dtype: object

# %%
plt1 = df['CompanyName'].value_counts().plot(kind = 'bar')
plt1.set_title('Companies Histogram', fontsize=20)
plt1.set_xlabel('Car company')
plt1.set_ylabel('Frequency of company')
# Out:
# Text(0, 0.5, 'Frequency of company')

# %%
plt2 = df['fueltype'].value_counts().plot(kind='bar')
plt2.set_title('Fuel Type Histogram')
plt2.set_xlabel('Fuel Type')
plt2.set_ylabel('Frequency of fuel type')
# Out:
# Text(0, 0.5, 'Frequency of fuel type')

# %%
plt3 = df['carbody'].value_counts().plot(kind='bar')
plt3.set_title('carbody Histogram',fontsize=14)
plt3.set_xlabel('carbody')
plt3.set_ylabel('Frequency of Carmodel')
# Out:
# Text(0, 0.5, 'Frequency of Carmodel')

# %%
plt3 = df['carbody'].value_counts().plot(kind='bar')
plt3.set_title('carbody Histogram',fontsize=14)
plt3.set_xlabel('carbody')
plt3.set_ylabel('Frequency of Carmodel')
# Out:
# Text(0, 0.5, 'Frequency of Carmodel')

# %%
plt4 = df['enginetype'].value_counts().plot(kind='bar')
plt4.set_title('enginetype histogram')
plt4.set_xlabel('enginetype')
plt4.set_ylabel('frequency of enginetype')
# Out:
# Text(0, 0.5, 'frequency of enginetype')

# %%
plt5 = df['doornumber'].value_counts().plot(kind='bar')
plt5.set_title('doornumber histogram')
plt5.set_xlabel('doornumber')
plt5.set_ylabel('frequency of doornumber')
# Out:
# Text(0, 0.5, 'frequency of doornumber')

# %%
object_columns = df.select_dtypes(include=['object'])

# %%
object_columns
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#     enginetype cylindernumber fuelsystem  CompanyName      Carmodel
# ...

# %%
object_columns.columns
# Out:
# Index(['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel',
#        'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem',
#        'CompanyName', 'Carmodel'],
#       dtype='object')

# %%
df = df.drop(object_columns.columns,axis=1)

# %%
#encoded the categorical data using label encoder
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
object_columns = object_columns.apply(LabelEncoder().fit_transform)

# %%
df.head()
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          3       88.6      168.8      64.1       48.8        2548
# 1          3       88.6      168.8      64.1       48.8        2548
# 2          1       94.5      171.2      65.5       52.4        2823
# 3          2       99.8      176.6      66.2       54.3        2337
# 4          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# 1       21          27  16500.0
# ...

# %%
df = df.join(object_columns)

# %%
df.head()
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          3       88.6      168.8      64.1       48.8        2548
# 1          3       88.6      168.8      64.1       48.8        2548
# 2          1       94.5      171.2      65.5       52.4        2823
# 3          2       99.8      176.6      66.2       54.3        2337
# 4          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  ...  aspiration  \
# 0         130       3.47    2.68               9.0  ...           0
# 1         130       3.47    2.68               9.0  ...           0
# 2         152       2.68    3.47               9.0  ...           0
# 3         109       3.19    3.40              10.0  ...           0
# 4         136       3.19    3.40               8.0  ...           0
#
#    doornumber  carbody  drivewheel  enginelocation  enginetype  \
# 0           1        0           2               0           0
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price', 'fueltype',
#        'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation',
#        'enginetype', 'cylindernumber', 'fuelsystem', 'CompanyName',
#        'Carmodel'],
#       dtype='object')

# %%
X = df.drop(['price'],axis=1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
df.columns
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price', 'fueltype',
#        'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation',
#        'enginetype', 'cylindernumber', 'fuelsystem', 'CompanyName',
#        'Carmodel'],
#       dtype='object')

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
lr = DecisionTreeRegressor()

lr.fit(X_train, y_train)

# Make predictions on the test set
y_pred = lr.predict(X_test)

# Evaluate the model

r2 = r2_score(y_test, y_pred)


print(f'R-squared: {r2}')
# Out:
# R-squared: 0.8799664752740045

# %%
X_test_values = X_test
y_test_predicted = lr.predict(X_test)
y_test_predicted_df = pd.DataFrame(pd.Series(y_test_predicted, name ='Predicted price'))
y_test_predicted_df.reset_index(drop=True, inplace=True)

y_test_df = pd.DataFrame(pd.Series(y_test, name='Actual Price'))
y_test_df.reset_index(drop=True, inplace=True)

train_test_df = pd.concat([y_test_df, y_test_predicted_df], axis=1)
train_test_df.head()
# Out:
#    Actual Price  Predicted price
# 0      7603.000           8238.0
# 1      9279.000           8558.0
# 2      6479.000           5399.0
# 3     18420.000          18950.0
# 4     17859.167          12764.0

# %%
import matplotlib.pyplot as plt

# Assuming y_true and y_pred are your actual and predicted values

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.show()

# %%
R̥R̥
